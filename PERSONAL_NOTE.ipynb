# %% [markdown]
# # How to prepare a forecasting script

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # After specifying the path, click on Tab to list all the files inside the path

# %%
file='W_C.xlsx'

# %%
data = pd.read_excel(file)

# %% [markdown]
# # Export the data into a data frame

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#                  HOURS  TEMP  RH  WIND DIRECTION  GUSTINESS  CAPE Unnamed: 7  \
# 0             12:00:00    30  62     1        SW          5   191        NaN
# 1             15:00:00    31  57     1         S          5   795        NaN
# 2             18:00:00    26  84     1         S          5   558        NaN
# 3             21:00:00    23  92     2        SW          6   285        NaN
# 4  1900-01-01 00:00:00    22  97     2         S          5   305        NaN
# 5  1900-01-01 03:00:00    22  98     1        SW          3   165        NaN
# 6  1900-01-01 06:00:00    23  98     2        SW          4    88        NaN
# 7  1900-01-01 09:00:00    26  80     2        NW          6   153        NaN
# 8  1900-01-01 12:00:00    29  64     2         W          6   891     SUNSET
#
#    Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0         NaN        DAY       NIGHT
# 1        TEMP         28          22
# 2          RH  74.166667       92.75
# 3  WIND FROM         NaN         NaN
# ...

# %%
df['HOURS']=pd.date_range(start='2022-10-28 12',end='2022-10-29 12',freq='3H')
df=df.set_index('HOURS')

# %%
df
# Out:
#                      TEMP  RH  WIND DIRECTION  GUSTINESS  CAPE Unnamed: 7  \
# HOURS
# 2022-10-28 12:00:00    30  62     1        SW          5   191        NaN
# 2022-10-28 15:00:00    31  57     1         S          5   795        NaN
# 2022-10-28 18:00:00    26  84     1         S          5   558        NaN
# 2022-10-28 21:00:00    23  92     2        SW          6   285        NaN
# 2022-10-29 00:00:00    22  97     2         S          5   305        NaN
# 2022-10-29 03:00:00    22  98     1        SW          3   165        NaN
# 2022-10-29 06:00:00    23  98     2        SW          4    88        NaN
# 2022-10-29 09:00:00    26  80     2        NW          6   153        NaN
# 2022-10-29 12:00:00    29  64     2         W          6   891     SUNSET
#
#                      Unnamed: 8 Unnamed: 9 Unnamed: 10
# HOURS
# 2022-10-28 12:00:00         NaN        DAY       NIGHT
# 2022-10-28 15:00:00        TEMP         28          22
# ...

# %% [markdown]
# df

# %%
g= df['TEMP']
F=df["RH"]

# %%
# fig, axes=plt.subplots(figsize=(6,4))

# %%
fig, axes=plt.subplots(figsize=(8,5))


TIM=['1200','1500','1800','2100','0000','0300','0600','0900','12:00']
# ax1=axes.twinx()
ax1=axes
ax1.plot(TIM,g,color='red',lw=1.5, ls="-", marker="*")
ax1.set_xlabel('Time (UTC)',fontsize=15)
ax1.set_ylabel('Temperature($^oc$)',color='red', fontsize=15)#'

ax2=axes.twinx()
# ax2=axes
ax2.plot(TIM,F,color='blue',lw=1.5, ls="-", marker="o")
# ax2.set_xlabel('Hours (UTC)',fontsize=15)
ax2.set_ylabel('Relative Humidity (%)',color='blue',fontsize=15)
# ax2.set_title('Timeseries and bar chart',fontsize=15)
ax2.set_title('Temperature and Relative Humidity for Kumasi',color='green', fontsize=15)
fig.savefig("T_r.jpeg")

ax1.tick_params(axis='y',colors='red')
ax2.tick_params(axis='y', colors='blue')

# %%
sns.jointplot(x='TEMP',y='RH',data=df, kind='kde')# hex,reg,kde

# %%
sns.displot(df, kind='kde')#bins=10

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, hue="DIRECTION")

# %%
sns.pairplot(df, hue="DIRECTION")#

# %%
sns.rugplot(df['RH'])
# Out:
# <AxesSubplot:xlabel='RH'>

# %%
sns.displot(df['TEMP'],kde=True)#kde means Kernel Density Estimation

# %% [markdown]
# Creating of finctions
# =
# There are two functions; functions that perform a task and functions that calculate and return a value.

# %%
def greet(b,d):
    print(f'Helllo {b} {d}')
    print('Please greet')

# %%
greet('Eric', 'Ayitah')
# Out:
# Helllo Eric Ayitah
# Please greet

# %%
def mas(*num):
    return num

# %%
mas(1,2,3,4,7,8)
# Out:
# (1, 2, 3, 4, 7, 8)

# %%
mas(7)
