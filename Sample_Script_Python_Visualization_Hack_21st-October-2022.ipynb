# %% [markdown]
# # Quick Python Visualization Hacks (21st October 2022)

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
a = [1,10,5,2,9,14,12]
plt.figure()
plt.subplot(3,2,1)
plt.plot(a)

plt.subplot(3,2,2)
plt.plot(np.random.rand(20))




plt.subplot(3,2,6)
plt.plot(np.random.rand(20))



plt.subplot(3,2,4)
plt.plot(np.random.rand(20))

# %%
fig, axes = plt.subplots(ncols=2, nrows=2)

axes[0,1].set_visible(False)

# %%
indices = [20, 50, 100, 2000, 30]
fig, axes = plt.subplots(ncols=2, nrows=2, figsize=(12, 8))

axes[0,0].plot(np.random.rand(indices[0]))
axes[0,0].set_title(str(indices[0]), fontsize=20)



axes[0,1].plot(np.random.rand(indices[1]))
axes[0,1].set_title(str(indices[1]), fontsize=20)



axes[1,0].plot(np.random.rand(indices[2]))
axes[1,0].set_title(str(indices[2]), fontsize=20)



axes[1,1].plot(np.random.rand(indices[3]))
axes[1,1].set_title(str(indices[3]), fontsize=20)
# Out:
# Text(0.5, 1.0, '2000')

# %% [markdown]
# # Conditional Statements & One-Liner Conditional Statements

# %%
if 5>2:
    print('Yes')
else:
    print('No')
# Out:
# Yes

# %%
'Yes' if 5>2 else 'No'
# Out:
# 'Yes'

# %%
r = len(indices)//c if len(indices)%c == 0 else len(indices)//c+1
# Out:
# 3

# %%
len(indices)#//c
7//3
# Out:
# 2

# %%
indices = [20, 50, 100, 2000, 30, 250,300, 30, ]
c = 3
r = len(indices)//c if len(indices)%c == 0 else len(indices)//c+1
fig, axes = plt.subplots(ncols=c, nrows=r, figsize=(12, 12))
for i,j in enumerate(indices):
    axes[i//c,i%c].plot(np.random.rand(j))
    axes[i//c,i%c].set_title(str(j))
