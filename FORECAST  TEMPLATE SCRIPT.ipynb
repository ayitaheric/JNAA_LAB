# %% [markdown]
# # How to prepare a forecasting script

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np

# %% [markdown]
# # After specifying the path, click on Tab to list all the files inside the path

# %%
file='W_C.xlsx'

# %%
data = pd.read_excel(file)

# %% [markdown]
# # Export the data into a data frame

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#                  HOURS  TEMP  RH  WIND DIRECTION  GUSTINESS  CAPE Unnamed: 7  \
# 0             12:00:00    28  78     1        SW          8   191        NaN
# 1             15:00:00    27  79     1         S          9   795        NaN
# 2             18:00:00    24  84     2         S          9   558        NaN
# 3             21:00:00    22  87     2        SW          8   285        NaN
# 4  1900-01-01 00:00:00    21  90     1         S          5   305        NaN
# 5  1900-01-01 03:00:00    22  93     1        SW          4   165        NaN
# 6  1900-01-01 06:00:00    22  94     2        SW          4    88        NaN
# 7  1900-01-01 09:00:00    25  80     2        NW          5   153        NaN
# 8  1900-01-01 12:00:00    29  77     0         W          8   891     SUNSET
#
#    Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0         NaN        DAY       NIGHT
# 1        TEMP         28          22
# 2          RH         82        88.5
# 3  WIND FROM         NaN         NaN
# 4  WIND SPEED   1.333333         1.5
# 5   WIND GUST   7.166667         6.5
# 6         NaN        446      328.25
# 7         NaN        NaN         NaN
# 8    17:51:00        NaN         NaN

# %%
df['HOURS']=pd.date_range(start='2021-10-15 12',end='2021-10-16 12',freq='3H')
df=df.set_index('HOURS')

# %%
df
# Out:
#                      TEMP  RH  WIND DIRECTION  GUSTINESS  CAPE Unnamed: 7  \
# HOURS
# 2021-10-15 12:00:00    28  78     1        SW          8   191        NaN
# 2021-10-15 15:00:00    27  79     1         S          9   795        NaN
# 2021-10-15 18:00:00    24  84     2         S          9   558        NaN
# 2021-10-15 21:00:00    22  87     2        SW          8   285        NaN
# 2021-10-16 00:00:00    21  90     1         S          5   305        NaN
# 2021-10-16 03:00:00    22  93     1        SW          4   165        NaN
# 2021-10-16 06:00:00    22  94     2        SW          4    88        NaN
# 2021-10-16 09:00:00    25  80     2        NW          5   153        NaN
# 2021-10-16 12:00:00    29  77     0         W          8   891     SUNSET
#
#                      Unnamed: 8 Unnamed: 9 Unnamed: 10
# HOURS
# 2021-10-15 12:00:00         NaN        DAY       NIGHT
# 2021-10-15 15:00:00        TEMP         28          22
# 2021-10-15 18:00:00          RH         82        88.5
# 2021-10-15 21:00:00  WIND FROM         NaN         NaN
# 2021-10-16 00:00:00  WIND SPEED   1.333333         1.5
# 2021-10-16 03:00:00   WIND GUST   7.166667         6.5
# 2021-10-16 06:00:00         NaN        446      328.25
# 2021-10-16 09:00:00         NaN        NaN         NaN
# 2021-10-16 12:00:00    17:51:00        NaN         NaN

# %% [markdown]
# df

# %%
g= df['TEMP']
F=df["RH"]

# %%
fig, axes=plt.subplots(figsize=(8,5))


# TIM=['1200','1500','1800','2100','0000','0300','0600','0900','12:00']
# ax1=axes.twinx()
ax1=axes
ax1.plot(df.index,g,color='blue',lw=1.5, ls="-", marker="*",label="Temperature")
ax1.set_xlabel('Hours (UTC)',fontsize=15)
ax1.set_ylabel('Temperature($^oc$)',color='red', fontsize=15)

ax2=axes.twinx()
# ax2=axes
ax2.plot(df.index,F,color='red',lw=1.5, ls="-", marker="o",label="Temperature")
# ax2.set_xlabel('Hours (UTC)',fontsize=15)
ax2.set_ylabel('Relative Humidity (%)',color='blue',fontsize=15)
# ax2.set_title('Timeseries and bar chart',fontsize=15)
# fig.savefig('Jun')
# Out:
# Text(0, 0.5, 'Relative Humidity (%)')
