# %% [markdown]
# TASK 4
# =

# %% [markdown]
# Read Kumasi, Accra, Kete_krachi and Wa dataset using pandas.
# - Rename the columns to suit the column elements
# - Create a datetime using the columns containing, year, month and day.
# - Find the annual rainfall total of all the datasets and visualise all the stations data in one figure
# - Find the annual Rainfall anomalies for each station
# - Visualise the yearly rainfall anomalies for each station by creating a subplot of 2 rows and 2 columns (each axis conatinaing visualisation for each station data)
# -  Save your graph as pdf
#
# ## NB:
# - make sure you label all graphs
# - Make use of comments and the markdown to make your script look presentable

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
#import cartopy
#import cartopy.crs as ccrs
#import cartopy.feature as cf
#import cartopy.io.shapereader as shapereader
import pandas as pd

from pathlib import Path

# %%
data_path = Path('')

# %%
# data = {
#     "Temperature": [30.2, 31.4, 32.5, 28.9],
#     "Rainfall": [21.2, 10.4, 0, 2],
#     "Wind Speed": [2.1, 3.4, 8.2, 4.1],
#     "Wind Direction": ["SW", "S", "N", "NE"],
# }

# # Create a dataframe from the data and set the keys as column headers
# df = pd.DataFrame(data, columns=data.keys())
# df

# %%
# atxt = np.loadtxt("GAUGE_PRECIP-20221019T102326Z-001/GAUGE_PRECIP/Kumasi_1983_2017_dRR_gapless.txt") #dtype='str,int')
# #print(atxt)

# %% [markdown]
# TASK 4
# =

# %% [markdown]
# Read Kumasi, Accra, Kete_krachi and Wa dataset using pandas.
# - Rename the columns to suit the column elements
# - Create a datetime using the columns containing, year, month and day.
# - Find the annual rainfall total of all the datasets and visualise all the stations data in one figure
# - Find the annual Rainfall anomalies for each station
# - Visualise the yearly rainfall anomalies for each station by creating a subplot of 2 rows and 2 columns (each axis conatinaing visualisation for each station data)
# -  Save your graph as pdf
#
# ## NB:
# - make sure you label all graphs
# - Make use of comments and the markdown to make your script look presentable

# %%
# atxt

# %%
Kumasi = pd.read_fwf("GAUGE_PRECIP-20221019T102326Z-001/GAUGE_PRECIP/Kumasi_1983_2017_dRR_gapless.txt" ,delimiter=" ")

# %%
Kumasi
# Out:
#        1983  01  01.1  0.00
# 0      1983   1     2   0.0
# 1      1983   1     3   0.0
# 2      1983   1     4   0.0
# 3      1983   1     5   0.0
# 4      1983   1     6   0.0
# ...     ...  ..   ...   ...
# 12778  2017  12    27   0.0
# 12779  2017  12    28   0.0
# 12780  2017  12    29   0.0
# 12781  2017  12    30   0.0
# 12782  2017  12    31   0.0
#
# [12783 rows x 4 columns]

# %%
#Naming the headings of all the stations
Kumasi = pd.read_fwf("GAUGE_PRECIP-20221019T102326Z-001/GAUGE_PRECIP/Kumasi_1983_2017_dRR_gapless.txt" ,delimiter=" ", header=None,names=['Year','Month','Day','Rainfall'])

# %%
Kumasi
# Out:
#        Year  Month  Day  Rainfall
# 0      1983      1    1       0.0
# 1      1983      1    2       0.0
# 2      1983      1    3       0.0
# 3      1983      1    4       0.0
# 4      1983      1    5       0.0
# ...     ...    ...  ...       ...
# 12779  2017     12   27       0.0
# 12780  2017     12   28       0.0
# 12781  2017     12   29       0.0
# 12782  2017     12   30       0.0
# 12783  2017     12   31       0.0
#
# [12784 rows x 4 columns]

# %%
Accra = pd.read_fwf("GAUGE_PRECIP-20221019T102326Z-001/GAUGE_PRECIP/Accra_1983_2017_dRR_gapless.txt" ,delimiter=" ", header=None,names=['Year','Month','Day','Rainfall'])

# %%
Accra
# Out:
#        Year  Month  Day  Rainfall
# 0      1983      1    1       0.0
# 1      1983      1    2       0.0
# 2      1983      1    3       0.0
# 3      1983      1    4       0.0
# 4      1983      1    5       0.0
# ...     ...    ...  ...       ...
# 12779  2017     12   27       0.0
# 12780  2017     12   28       0.0
# 12781  2017     12   29       0.0
# 12782  2017     12   30       0.0
# 12783  2017     12   31       0.0
#
# [12784 rows x 4 columns]

# %%
Kete = pd.read_fwf("GAUGE_PRECIP-20221019T102326Z-001/GAUGE_PRECIP/Kete_Krachi_1983_2017_dRR_gapless.txt" ,delimiter=" ", header=None,names=['Year','Month','Day','Rainfall'])

# %%
Kete
# Out:
#        Year  Month  Day  Rainfall
# 0      1983      1    1       0.0
# 1      1983      1    2       0.0
# 2      1983      1    3       0.0
# 3      1983      1    4       0.0
# 4      1983      1    5       0.0
# ...     ...    ...  ...       ...
# 12779  2017     12   27       0.0
# 12780  2017     12   28       0.0
# 12781  2017     12   29       0.0
# 12782  2017     12   30       0.0
# 12783  2017     12   31       0.0
#
# [12784 rows x 4 columns]

# %%
Wa = pd.read_fwf("GAUGE_PRECIP-20221019T102326Z-001/GAUGE_PRECIP/Wa_1983_2017_dRR_gapless.txt" ,delimiter=" ", header=None,names=['Year','Month','Day','Rainfall'])

# %%
Wa
# Out:
#        Year  Month  Day  Rainfall
# 0      1983      1    1       0.0
# 1      1983      1    2       0.0
# 2      1983      1    3       0.0
# 3      1983      1    4       0.0
# 4      1983      1    5       0.0
# ...     ...    ...  ...       ...
# 12779  2017     12   27       0.0
# 12780  2017     12   28       0.0
# 12781  2017     12   29       0.0
# 12782  2017     12   30       0.0
# 12783  2017     12   31       0.0
#
# [12784 rows x 4 columns]

# %%
#df.describe()

# %%
#df.count()

# %%
# df.sum(0,3)

# %%
#dtaetime of Kumasi data
Kumasi["date"] = pd.to_datetime(Kumasi[["Year", "Month", "Day"]])
Kumasi
# Out:
#        Year  Month  Day  Rainfall       date
# 0      1983      1    1       0.0 1983-01-01
# 1      1983      1    2       0.0 1983-01-02
# 2      1983      1    3       0.0 1983-01-03
# 3      1983      1    4       0.0 1983-01-04
# 4      1983      1    5       0.0 1983-01-05
# ...     ...    ...  ...       ...        ...
# 12779  2017     12   27       0.0 2017-12-27
# 12780  2017     12   28       0.0 2017-12-28
# 12781  2017     12   29       0.0 2017-12-29
# 12782  2017     12   30       0.0 2017-12-30
# 12783  2017     12   31       0.0 2017-12-31
#
# [12784 rows x 5 columns]

# %%
Accra["date"] = pd.to_datetime(Accra[["Year", "Month", "Day"]])
Accra
# Out:
#        Year  Month  Day  Rainfall       date
# 0      1983      1    1       0.0 1983-01-01
# 1      1983      1    2       0.0 1983-01-02
# 2      1983      1    3       0.0 1983-01-03
# 3      1983      1    4       0.0 1983-01-04
# 4      1983      1    5       0.0 1983-01-05
# ...     ...    ...  ...       ...        ...
# 12779  2017     12   27       0.0 2017-12-27
# 12780  2017     12   28       0.0 2017-12-28
# 12781  2017     12   29       0.0 2017-12-29
# 12782  2017     12   30       0.0 2017-12-30
# 12783  2017     12   31       0.0 2017-12-31
#
# [12784 rows x 5 columns]

# %%
Wa["date"] = pd.to_datetime(Wa[["Year", "Month", "Day"]])
Wa
# Out:
#        Year  Month  Day  Rainfall       date
# 0      1983      1    1       0.0 1983-01-01
# 1      1983      1    2       0.0 1983-01-02
# 2      1983      1    3       0.0 1983-01-03
# 3      1983      1    4       0.0 1983-01-04
# 4      1983      1    5       0.0 1983-01-05
# ...     ...    ...  ...       ...        ...
# 12779  2017     12   27       0.0 2017-12-27
# 12780  2017     12   28       0.0 2017-12-28
# 12781  2017     12   29       0.0 2017-12-29
# 12782  2017     12   30       0.0 2017-12-30
# 12783  2017     12   31       0.0 2017-12-31
#
# [12784 rows x 5 columns]

# %%
Kete["date"] = pd.to_datetime(Kete[["Year", "Month", "Day"]])
Kete
# Out:
#        Year  Month  Day  Rainfall       date
# 0      1983      1    1       0.0 1983-01-01
# 1      1983      1    2       0.0 1983-01-02
# 2      1983      1    3       0.0 1983-01-03
# 3      1983      1    4       0.0 1983-01-04
# 4      1983      1    5       0.0 1983-01-05
# ...     ...    ...  ...       ...        ...
# 12779  2017     12   27       0.0 2017-12-27
# 12780  2017     12   28       0.0 2017-12-28
# 12781  2017     12   29       0.0 2017-12-29
# 12782  2017     12   30       0.0 2017-12-30
# 12783  2017     12   31       0.0 2017-12-31
#
# [12784 rows x 5 columns]

# %%
Kum=Kumasi[["Rainfall", "date"]].set_index("date")  #set the "date" column as the index

# %%
Kum
# Out:
#             Rainfall
# date
# 1983-01-01       0.0
# 1983-01-02       0.0
# 1983-01-03       0.0
# 1983-01-04       0.0
# 1983-01-05       0.0
# ...              ...
# 2017-12-27       0.0
# 2017-12-28       0.0
# 2017-12-29       0.0
# 2017-12-30       0.0
# 2017-12-31       0.0
#
# [12784 rows x 1 columns]

# %%
Acc=Accra[["Rainfall", "date"]].set_index("date")

# %%
Acc
# Out:
#             Rainfall
# date
# 1983-01-01       0.0
# 1983-01-02       0.0
# 1983-01-03       0.0
# 1983-01-04       0.0
# 1983-01-05       0.0
# ...              ...
# 2017-12-27       0.0
# 2017-12-28       0.0
# 2017-12-29       0.0
# 2017-12-30       0.0
# 2017-12-31       0.0
#
# [12784 rows x 1 columns]

# %%
Waa=Wa[["Rainfall", "date"]].set_index("date")

# %%
Waa
# Out:
#             Rainfall
# date
# 1983-01-01       0.0
# 1983-01-02       0.0
# 1983-01-03       0.0
# 1983-01-04       0.0
# 1983-01-05       0.0
# ...              ...
# 2017-12-27       0.0
# 2017-12-28       0.0
# 2017-12-29       0.0
# 2017-12-30       0.0
# 2017-12-31       0.0
#
# [12784 rows x 1 columns]

# %%
Ket=Kete[["Rainfall", "date"]].set_index("date")

# %%
Ket
# Out:
#             Rainfall
# date
# 1983-01-01       0.0
# 1983-01-02       0.0
# 1983-01-03       0.0
# 1983-01-04       0.0
# 1983-01-05       0.0
# ...              ...
# 2017-12-27       0.0
# 2017-12-28       0.0
# 2017-12-29       0.0
# 2017-12-30       0.0
# 2017-12-31       0.0
#
# [12784 rows x 1 columns]

# %%
Kum['Rainfall']=Kum.Rainfall.astype('float')

# %%
AnnualMaxRainfall=Kum.resample('y').sum() #Resampling the data into yearly total

# %%
AnnualMaxRainfall
# Out:
#             Rainfall
# date
# 1983-12-31    906.00
# 1984-12-31   1283.90
# 1985-12-31   1669.20
# 1986-12-31   1132.60
# 1987-12-31   1303.60
# 1988-12-31   1420.40
# 1989-12-31   1463.90
# 1990-12-31   1219.20
# 1991-12-31   1275.80
# 1992-12-31    963.50
# 1993-12-31   1399.85
# 1994-12-31   1111.10
# 1995-12-31   1327.20
# 1996-12-31   1040.90
# 1997-12-31   1303.70
# 1998-12-31   1092.20
# 1999-12-31   1428.90
# 2000-12-31   1488.50
# 2001-12-31   1185.80
# 2002-12-31   1568.30
# 2003-12-31   1349.20
# 2004-12-31   1415.30
# 2005-12-31   1231.00
# 2006-12-31   1159.80
# 2007-12-31   1794.90
# 2008-12-31   1452.00
# 2009-12-31   1530.70
# 2010-12-31   1197.50
# 2011-12-31   1521.80
# 2012-12-31   1521.40
# 2013-12-31   1348.70
# 2014-12-31   1354.20
# 2015-12-31   1234.80
# 2016-12-31   1333.30
# 2017-12-31   1476.00

# %%
Acc['Rainfall']=Acc.Rainfall.astype('float')

# %%
AnnualMaxRainfall2=Acc.resample('y').sum()

# %%
AnnualMaxRainfall2
# Out:
#             Rainfall
# date
# 1983-12-31     333.1
# 1984-12-31     704.9
# 1985-12-31     680.6
# 1986-12-31     545.2
# 1987-12-31     640.3
# 1988-12-31     888.9
# 1989-12-31     656.7
# 1990-12-31     567.9
# 1991-12-31     908.3
# 1992-12-31     557.0
# 1993-12-31     509.3
# 1994-12-31     547.9
# 1995-12-31     829.8
# 1996-12-31     716.6
# 1997-12-31    1023.5
# 1998-12-31     413.6
# 1999-12-31     641.8
# 2000-12-31     512.2
# 2001-12-31     871.7
# 2002-12-31     710.0
# 2003-12-31     787.0
# 2004-12-31     573.8
# 2005-12-31     777.6
# 2006-12-31     648.4
# 2007-12-31     867.6
# 2008-12-31    1064.7
# 2009-12-31     656.2
# 2010-12-31     824.0
# 2011-12-31    1014.4
# 2012-12-31     594.7
# 2013-12-31     527.0
# 2014-12-31     987.9
# 2015-12-31     784.6
# 2016-12-31     880.3
# 2017-12-31     862.6

# %%
Waa['Rainfall']=Waa.Rainfall.astype('float')

# %%
AnnualMaxRainfall3=Waa.resample('y').sum()

# %%
AnnualMaxRainfall3
# Out:
#             Rainfall
# date
# 1983-12-31    670.30
# 1984-12-31    936.70
# 1985-12-31   1060.70
# 1986-12-31    522.90
# 1987-12-31    776.60
# 1988-12-31    930.50
# 1989-12-31   1042.30
# 1990-12-31    906.30
# 1991-12-31   1007.80
# 1992-12-31    880.49
# 1993-12-31   1130.20
# 1994-12-31    999.80
# 1995-12-31   1244.10
# 1996-12-31   1034.60
# 1997-12-31   1257.80
# 1998-12-31    767.30
# 1999-12-31   1290.40
# 2000-12-31   1141.20
# 2001-12-31   1005.80
# 2002-12-31    939.30
# 2003-12-31   1199.40
# 2004-12-31   1080.20
# 2005-12-31   1060.80
# 2006-12-31    910.80
# 2007-12-31    896.70
# 2008-12-31   1275.10
# 2009-12-31   1141.70
# 2010-12-31   1032.20
# 2011-12-31    946.00
# 2012-12-31    978.80
# 2013-12-31    961.77
# 2014-12-31    914.40
# 2015-12-31    811.60
# 2016-12-31    921.47
# 2017-12-31    805.30

# %%
Ket['Rainfall']=Ket.Rainfall.astype('float')

# %%
AnnualMaxRainfall4=Ket.resample('y').sum()

# %%
AnnualMaxRainfall4
# Out:
#             Rainfall
# date
# 1983-12-31   1073.50
# 1984-12-31   1535.20
# 1985-12-31   1336.80
# 1986-12-31   1273.23
# 1987-12-31   1251.40
# 1988-12-31   1064.40
# 1989-12-31   1279.50
# 1990-12-31   1336.70
# 1991-12-31   2031.50
# 1992-12-31    970.70
# 1993-12-31   1003.20
# 1994-12-31    999.60
# 1995-12-31   1680.80
# 1996-12-31   1445.40
# 1997-12-31   1387.90
# 1998-12-31    982.50
# 1999-12-31   1380.80
# 2000-12-31   1275.60
# 2001-12-31    815.60
# 2002-12-31   1453.80
# 2003-12-31   1423.50
# 2004-12-31   1400.60
# 2005-12-31   1198.80
# 2006-12-31   1033.30
# 2007-12-31   1148.60
# 2008-12-31   1753.50
# 2009-12-31   1617.50
# 2010-12-31   1107.20
# 2011-12-31   1229.80
# 2012-12-31   1295.00
# 2013-12-31    886.91
# 2014-12-31   1275.90
# 2015-12-31    993.10
# 2016-12-31   1078.30
# 2017-12-31   1164.40

# %% [markdown]
# ANNUAL RAINFALL ANOMALIES
# =

# %%
K_mean=AnnualMaxRainfall['Rainfall'].mean()
K_ano=AnnualMaxRainfall['Rainfall']- K_mean

# %%
Acc_mean= AnnualMaxRainfall2['Rainfall'].mean()
Acc_ano= AnnualMaxRainfall2['Rainfall']- Acc_mean

# %%
Wa_mean = AnnualMaxRainfall3['Rainfall'].mean()
W_ano = AnnualMaxRainfall3['Rainfall']- Wa_mean

# %%
Ke_mean =AnnualMaxRainfall4['Rainfall'].mean()
Ke_ano =AnnualMaxRainfall4['Rainfall']-Ke_mean

# %%
Ke_ano
# Out:
# date
# 1983-12-31   -188.915429
# 1984-12-31    272.784571
# 1985-12-31     74.384571
# 1986-12-31     10.814571
# 1987-12-31    -11.015429
# 1988-12-31   -198.015429
# 1989-12-31     17.084571
# 1990-12-31     74.284571
# 1991-12-31    769.084571
# 1992-12-31   -291.715429
# 1993-12-31   -259.215429
# 1994-12-31   -262.815429
# 1995-12-31    418.384571
# 1996-12-31    182.984571
# 1997-12-31    125.484571
# 1998-12-31   -279.915429
# 1999-12-31    118.384571
# 2000-12-31     13.184571
# 2001-12-31   -446.815429
# 2002-12-31    191.384571
# 2003-12-31    161.084571
# 2004-12-31    138.184571
# 2005-12-31    -63.615429
# 2006-12-31   -229.115429
# 2007-12-31   -113.815429
# 2008-12-31    491.084571
# 2009-12-31    355.084571
# 2010-12-31   -155.215429
# 2011-12-31    -32.615429
# 2012-12-31     32.584571
# 2013-12-31   -375.505429
# 2014-12-31     13.484571
# 2015-12-31   -269.315429
# 2016-12-31   -184.115429
# 2017-12-31    -98.015429
# Freq: A-DEC, Name: Rainfall, dtype: float64

# %%
years=np.arange(1983,2018)

# %%
plt.figure(figsize=(10,6))
plt.bar(years,K_ano)
plt.title('Annual Rainfall anomalies for each station')
# Out:
# Text(0.5, 1.0, 'Annual Rainfall anomalies for each station')

# %%
fig, axes= plt.subplots(ncols=2, nrows=2, figsize=(8,6))
plt.subplots_adjust(hspace = 0.4, wspace = 0.3)
ax1 = axes[0,0]
ax1.bar(years, K_ano)

ax1.set_xlabel('Year',fontsize=10)
ax1.set_ylabel('Annual Rainfall Anomalies', fontsize=10)
ax1.set_title('Annual Rainfall Anomalies for Kumasi',fontsize=10)
#fig.savefig('bar_temp.jpeg')

#########################################################
ax2 = axes[0,1]
ax2.bar(years, Acc_ano)

ax2.set_xlabel('Year',fontsize=10)
ax2.set_ylabel('Annual Rainfall Anomalies', fontsize=10)
ax2.set_title('Annual Rainfall Anomalies for Accra',fontsize=10)
#fig.savefig('bar_temp.jpeg')


ax3 = axes[1,0]
ax3.bar(years, W_ano)

ax3.set_xlabel('Year',fontsize=10)
ax3.set_ylabel('Annual Rainfall Anomalies', fontsize=10)
ax3.set_title('Annual Rainfall Anomalies for Wa',fontsize=10)


ax4 = axes[1,1]
ax4.bar(years, Ke_ano)

ax4.set_xlabel('Year',fontsize=10)
ax4.set_ylabel('Annual Rainfall Anomalies', fontsize=10)
ax4.set_title('Annual Rainfall Anomalies for Kete Krachi',fontsize=10)
# Out:
# Text(0.5, 1.0, 'Annual Rainfall Anomalies for Kete Krachi')

# %%
fig=plt.figure(figsize=(15,10))


plt.plot(AnnualMaxRainfall4,color='green', label ='Kete_Krachi')
# # plt.plot(x,y, label ='cos')
plt.plot(AnnualMaxRainfall, color='red', label= 'Kumasi')
plt.plot(AnnualMaxRainfall2, color='blue', label= 'Accra')
plt.plot(AnnualMaxRainfall3, color='orange', label= 'Wa')

plt.legend()

plt.xlabel('Year',fontsize=20)
plt.ylabel('Rainfall', fontsize=20)
plt.title('Annual Rainfall Total ', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Annual Rainfall Total ')
