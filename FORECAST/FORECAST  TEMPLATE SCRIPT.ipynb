# %% [markdown]
# # How to prepare a forecasting script

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np

# %% [markdown]
# # After specifying the path, click on Tab to list all the files inside the path

# %%
file='ww.xlsx'

# %%
data = pd.read_excel(file)

# %% [markdown]
# # Export the data into a data frame

# %%
df= pd.DataFrame(data)

# %%
df
# Out:
#                  HOURS  TEMP  RH  WIND DIRECTION  GUSTINESS  CAPE Unnamed: 7  \
# 0             12:00:00    32  54     3        SW          8  1626        NaN
# 1             15:00:00    34  47     2         S          7   722        NaN
# 2             18:00:00    25  90     1         S          6   795        NaN
# 3             21:00:00    24  95     2        SW          5   560        NaN
# 4  1900-01-01 00:00:00    23  97     2         S          4   564        NaN
# 5  1900-01-01 03:00:00    23  98     2        SW          5   614        NaN
# 6  1900-01-01 06:00:00    23  97     2        SW          6   880        NaN
# 7  1900-01-01 09:00:00    24  95     3        NW          6   957        NaN
# 8  1900-01-01 12:00:00    27  82     1         W          6  1587     SUNSET
#
#    Unnamed: 8 Unnamed: 9 Unnamed: 10
# 0         NaN        DAY       NIGHT
# 1        TEMP         28          22
# 2          RH       77.5          95
# 3  WIND FROM         NaN         NaN
# ...

# %%
df['HOURS']=pd.date_range(start='2022-12-24 12',end='2022-12-25 12',freq='3H')
df=df.set_index('HOURS')

# %%
df
# Out:
#                      TEMP  RH  WIND DIRECTION  GUSTINESS  CAPE Unnamed: 7  \
# HOURS
# 2022-12-24 12:00:00    32  54     3        SW          8  1626        NaN
# 2022-12-24 15:00:00    34  47     2         S          7   722        NaN
# 2022-12-24 18:00:00    25  90     1         S          6   795        NaN
# 2022-12-24 21:00:00    24  95     2        SW          5   560        NaN
# 2022-12-25 00:00:00    23  97     2         S          4   564        NaN
# 2022-12-25 03:00:00    23  98     2        SW          5   614        NaN
# 2022-12-25 06:00:00    23  97     2        SW          6   880        NaN
# 2022-12-25 09:00:00    24  95     3        NW          6   957        NaN
# 2022-12-25 12:00:00    27  82     1         W          6  1587     SUNSET
#
#                      Unnamed: 8 Unnamed: 9 Unnamed: 10
# HOURS
# 2022-12-24 12:00:00         NaN        DAY       NIGHT
# 2022-12-24 15:00:00        TEMP         28          22
# ...

# %% [markdown]
# df

# %%
g= df['TEMP']
F=df["RH"]

# %%
fig, axes=plt.subplots(figsize=(8,5))


TIM=['12','15','18','21','00','03','06','09','$12$']
# ax1=axes.twinx()
ax1=axes
ax1.plot(TIM,g,color='RED',lw=2, ls="-", marker="*")
ax1.set_xlabel('Time (UTC)',fontsize=15)
ax1.set_ylabel('Temperature($^oc$)',color='red', fontsize=15)

ax2=axes.twinx()
# ax2=axes
ax2.plot(TIM,F,color='BLUE',lw=2, ls="-", marker="o")
# ax2.set_xlabel('Hours (UTC)',fontsize=15)
ax2.set_ylabel('Relative Humidity (%)',color='blue',fontsize=15)
# ax2.set_title('Timeseries and bar chart',fontsize=15)
ax2.set_title('TEMPERATURE AND RELATIVE HUMIDITY FOR KUMASI.',color='black', fontsize=15)
ax2.tick_params(axis='y', colors='blue')
ax1.tick_params(axis='y', colors='red')
fig.savefig("h.tiff")

# %%
4+3
# Out:
# 7
