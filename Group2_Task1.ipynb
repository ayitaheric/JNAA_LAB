# %% [markdown]
# TASK 1
# =
# Read the rr_temp_rh_24_30May21.csv. The file contains gridded data, the columns describe lat: latitude and lon: longitude for each datapoint, rr: total rainfall, tn weekly-mean daily-minimum temperature, tx: weekly-mean daily-maximum temperature and rh mean relative humidity
# <ol>
# <li> Generate spatial map for rainfall, maximum and minimum temperature and relative humidity </li>
# <li> Save figure to pdf and png </li>
# <li> Interpret the figures </li>
# </ol>

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
import cartopy
import cartopy.crs as ccrs
import cartopy.feature as cf
import cartopy.io.shapereader as shapereader
import pandas as pd
from pathlib import Path

# %%
drr = np.genfromtxt("rr_temp_rh_24_30May21.csv", delimiter=",", skip_header=1)
# stn = np.genfromtxt("rr_temp_rh_24_30May21.csv", delimiter=",", skip_header=1, usecols=1, dtype='str')

lat =drr[:,0]
lon =drr[:,1]
rr  = drr[:,2]
tx = drr[:,3]
tn = drr[:,4]
rh = drr[:,5]

# %%
delimiter=",",

# %%
drr
# Out:
# array([[11.1637506, -0.280419 ,  4.9334192, 36.2483521, 26.2838516,
#         48.000679 ],
#        [11.1137514, -0.380419 ,  7.9720955, 36.4342842, 26.4156952,
#         47.3204727],
#        [11.1137514, -0.280419 ,  4.4984193, 36.2509613, 26.2900066,
#         47.9930153],
#        ...,
#        [ 4.763751 , -2.0804191,  7.5646267, 31.3550129, 25.5790215,
#         75.7629776],
#        [ 4.763751 , -2.0304191,  9.4561901, 31.5191727, 25.6382923,
#         75.3197632],
#        [ 4.763751 , -1.980419 , 11.9670143, 31.6822319, 25.712389 ,
#         74.9625397]])

# %%
#shp_path ='gh_wgs16dregions.shp'
gh_shapes = list(shapereader.Reader(str('gh_wgs16dregions.shp')).geometries())

# %%
fig = plt.figure(figsize=(10,10))
# create axes with specific proojection
ax = plt.axes(projection=ccrs.PlateCarree())

#Alternative 
#fig, ax = plt.subplots( figsize=(10,10),subplot_kw={'projection': ccrs.PlateCarree()})


# set the domain lat lon extent
ax.set_extent([-4, 2, 4, 11.5], crs=ccrs.PlateCarree())

# add the administrative borders from the shapefile
ax.add_geometries(gh_shapes, ccrs.PlateCarree(), edgecolor='black', facecolor='none', alpha=0.8)

# and add country borders, ocean, land and lake borders from cartopy's set of features
ax.add_feature(cf.BORDERS)
ax.add_feature(cartopy.feature.COASTLINE)#OCEAN
#ax.add_feature(cartopy.feature.LAND, edgecolor='black')
# ax.add_feature(cf.LAKES, edgecolor='black')


ax.set(title='Total Rainfall')
splot = ax.scatter(lon,lat,30,c=rr,cmap =cm.get_cmap('Blues'), alpha=1)
fig.colorbar(splot,label="Rainfall (mm)", orientation="vertical", extend='both')

# %%
fig = plt.figure(figsize=(10,10))
# create axes with specific proojection
ax = plt.axes(projection=ccrs.PlateCarree())

#Alternative 
#fig, ax = plt.subplots( figsize=(10,10),subplot_kw={'projection': ccrs.PlateCarree()})


# set the domain lat lon extent
ax.set_extent([-4, 2, 4, 11.5], crs=ccrs.PlateCarree())

# add the administrative borders from the shapefile
ax.add_geometries(gh_shapes, ccrs.PlateCarree(), edgecolor='black', facecolor='none', alpha=0.8)

# and add country borders, ocean, land and lake borders from cartopy's set of features
ax.add_feature(cf.BORDERS)
ax.add_feature(cartopy.feature.COASTLINE)#OCEAN
#ax.add_feature(cartopy.feature.LAND, edgecolor='black')
# ax.add_feature(cf.LAKES, edgecolor='black')


ax.set(title='Weekly-Mean Daily-Minimum Temperature')
splot = ax.scatter(lon,lat,30,c=tn,cmap =cm.get_cmap('Reds'), alpha=1)
fig.colorbar(splot,label="Temperature $^0C$", orientation="vertical", extend='both')

# %%
fig = plt.figure(figsize=(10,10))
# create axes with specific proojection
ax = plt.axes(projection=ccrs.PlateCarree())

#Alternative 
#fig, ax = plt.subplots( figsize=(10,10),subplot_kw={'projection': ccrs.PlateCarree()})


# set the domain lat lon extent
ax.set_extent([-4, 2, 4, 11.5], crs=ccrs.PlateCarree())

# add the administrative borders from the shapefile
ax.add_geometries(gh_shapes, ccrs.PlateCarree(), edgecolor='black', facecolor='none', alpha=0.8)

# and add country borders, ocean, land and lake borders from cartopy's set of features
ax.add_feature(cf.BORDERS)
ax.add_feature(cartopy.feature.COASTLINE) # OCEAN
#ax.add_feature(cartopy.feature.LAND, edgecolor='black')
# ax.add_feature(cf.LAKES, edgecolor='black')


ax.set(title='Weekly-Mean Daily-Maximum Temperature  ')
splot = ax.scatter(lon,lat,30,c=tx,cmap =cm.get_cmap('Reds'), alpha=1)
fig.colorbar(splot,label=" Temperature $^oC$", orientation="vertical", extend='both')

# %%
fig = plt.figure(figsize=(10,10))
# create axes with specific proojection
ax = plt.axes(projection=ccrs.PlateCarree())

#Alternative 
#fig, ax = plt.subplots( figsize=(10,10),subplot_kw={'projection': ccrs.PlateCarree()})


# set the domain lat lon extent
ax.set_extent([-4, 2, 4, 11.5], crs=ccrs.PlateCarree())

# add the administrative borders from the shapefile
ax.add_geometries(gh_shapes, ccrs.PlateCarree(), edgecolor='black', facecolor='none', alpha=0.8)

# and add country borders, ocean, land and lake borders from cartopy's set of features
ax.add_feature(cf.BORDERS)
ax.add_feature(cartopy.feature.COASTLINE)#OCEAN
#ax.add_feature(cartopy.feature.LAND, edgecolor='black')
# ax.add_feature(cf.LAKES, edgecolor='black')


ax.set(title='Mean Relative Humidity ')
splot = ax.scatter(lon,lat,30,c=rr,cmap =cm.get_cmap('Blues'), alpha=1)
fig.colorbar(splot,label="Relative Humidity (%)", orientation="vertical", extend='both')

# %%
# fig = plt.figure(figsize=(10,10))
# create axes with specific proojection
# ax = plt.axes(projection=ccrs.PlateCarree())

#Alternative 
fig, axes = plt.subplots(nrows=2,ncols=2, figsize=(10,10),subplot_kw={'projection': ccrs.PlateCarree()})
axes[0,0].coastlines()
axes[0,1].coastlines()
axes[1,0].coastlines()
axes[1,1].coastlines()


# set the domain lat lon extent
axes[0,0].set_extent([-4, 2, 4, 12], crs=ccrs.PlateCarree())
axes[0,1].set_extent([-4, 2, 4, 12], crs=ccrs.PlateCarree())
axes[1,0].set_extent([-4, 2, 4, 12], crs=ccrs.PlateCarree())
axes[1,1].set_extent([-4, 2, 4, 12], crs=ccrs.PlateCarree())


axes[0,0].add_geometries(gh_shapes, ccrs.PlateCarree(), edgecolor='black', facecolor='none', alpha=0.8)
axes[0,1].add_geometries(gh_shapes, ccrs.PlateCarree(), edgecolor='black', facecolor='none', alpha=0.8)
axes[1,0].add_geometries(gh_shapes, ccrs.PlateCarree(), edgecolor='black', facecolor='none', alpha=0.8)
axes[1,1].add_geometries(gh_shapes, ccrs.PlateCarree(), edgecolor='black', facecolor='none', alpha=0.8)

axes[0,0].add_feature(cf.BORDERS)
axes[0,1].add_feature(cf.BORDERS)
axes[1,0].add_feature(cf.BORDERS)
axes[1,1].add_feature(cf.BORDERS)



axes[0,0].set(title='Total Rainfall')
axes[0,1].set(title='Mean Relative Humidity')
axes[1,0].set(title='Weekly-Mean Daily-Minimum Temperature ')
axes[1,1].set(title='Weekly-Mean Daily-Maximum Temperature ')


plot1 =axes[0,0].scatter(lon,lat,25,c=rr,cmap=cm.jet, alpha=1)
splot2 =axes[0,1].scatter(lon,lat,25,c=rh,cmap=cm.jet, alpha=1)
splot3 =axes[1,0].scatter(lon,lat,25,c=tn,cmap=cm.jet, alpha=1)
splot4 =axes[1,1].scatter(lon,lat,25,c=tx,cmap=cm.jet, alpha=1)



# splot1 =axes[0,0].scatter(lon,lat,25,c=rr,cmap=cm.get_cmap('Blues'), alpha=1)
# splot2 =axes[0,1].scatter(lon,lat,25,c=rh,cmap=cm.get_cmap('Blues'), alpha=1)
# splot3 =axes[1,0].scatter(lon,lat,25,c=tn,cmap=cm.get_cmap('Reds'), alpha=1)
# splot4 =axes[1,1].scatter(lon,lat,25,c=tx,cmap=cm.get_cmap('Reds'), alpha=1)
cb3=fig.add_axes([0.48,0.12,0.03,0.36])
cbar3=fig.colorbar(splot3,cax=cb3, extend='both', label="Temperature $^0C$" )

cb4=fig.add_axes([0.87,0.12,0.03,0.35])
cbar4=fig.colorbar(splot4,cax=cb4, extend='both',label=" Temperature $^oC$" )


cb2=fig.add_axes([0.87,0.52,0.03,0.35])
cbar2=fig.colorbar(splot2,cax=cb2, extend='both',label="Relative Humidity (%)" )


cb1=fig.add_axes([0.48,0.52,0.03,0.36])
cbar1=fig.colorbar(splot1,cax=cb1, extend='both',label="Rainfall (mm)" )








# c3=fig.add_axes([0.48,0.12,0.03,0.36])
# cr3=fig.colorbar(splot3,cax=c3, extend='both', label="Temperature $^0C$" )

# cb4=fig.add_axes([0.87,0.12,0.03,0.35])
# cr4=fig.colorbar(splot4,cax=c4, extend='both',label=" Temperature $^oC$" )


# cb2=fig.add_axes([0.87,0.52,0.03,0.35])
# cr2=fig.colorbar(splot2,cax=c2, extend='both',label="Relative Humidity (%)" )


# cb1=fig.add_axes([0.48,0.52,0.03,0.36])
# cr1=fig.colorbar(splot1,cax=c1, extend='both',label="Rainfall (mm)" )



# add the administrative borders from the shapefile
# ax.add_geometries(adm1_shapes, ccrs.PlateCarree(), edgecolor='black', facecolor='none', alpha=0.8)

# and add country borders, ocean, land and lake borders from cartopy's set of features
# ax.add_feature(cf.BORDERS)
# ax.add_feature(cartopy.feature.OCEAN)
# ax.add_feature(cartopy.feature.LAND, edgecolor='black')
# ax.add_feature(cf.LAKES, edgecolor='black')


# ax.set(title='Relative Humidity')
# splot = ax.scatter(lon,lat,200,c=rh,cmap =cm.get_cmap('Blues'), alpha=1)
# fig.colorbar(splot,label="Mean Relative Humidity (%)", orientation="vertical", extend='both')

# %%
lon
# Out:
# array([-0.280419 , -0.380419 , -0.280419 , ..., -2.0804191, -2.0304191,
#        -1.980419 ])

# %%
lat
# Out:
# array([11.1637506, 11.1137514, 11.1137514, ...,  4.763751 ,  4.763751 ,
#         4.763751 ])

# %%
f=[2,3,9,8]
np.sum(f)
# Out:
# 22

# %%
np.array(np.arange(4))

# %%
h=9.79976655
np.round(h,1)

# %%
y=np.arange(361)

# %%
y

# %%
m=np.sin(np.deg2rad(y))

# %%
m

# %%
fig, axes = plt.subplots(ncols=2,nrows=2, figsize=(8, 4))

axes[0].set_title("subplot 1")
axes[1].set_title("subplot 2")
axes[2].set_title("subplot 3")
axes[3].set_title("subplot 4")
