# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
data=pd.read_csv('GORIGO_2013LH.csv',names=['Year','Month','Day','Value'])
#

# %%
data
# Out:
#       Year  Month  Day      Value
# 0     2013      1    1 -21652.240
# 1     2013      1    1 -20552.070
# 2     2013      1    1 -19609.060
# 3     2013      1    1 -18760.350
# 4     2013      1    1 -17974.510
# ...    ...    ...  ...        ...
# 8755  2013     12   31 -10430.450
# 8756  2013     12   31  -8827.341
# 8757  2013     12   31  -7978.635
# 8758  2013     12   31  -7475.698
# 8759  2013     12   31  -7664.299
#
# [8760 rows x 4 columns]

# %%
plt.plot(data)

# %%
plt.plot(data.Month,data.Value)

# %%
dat=pd.read_csv('GORIGO_2014LH.csv',names=['Year','Month','Day','Value'])

# %%
dat
# Out:
#       Year  Month  Day      Value
# 0     2014      1    1  -8515.789
# 1     2014      1    1  -8236.718
# 2     2014      1    1  -8794.859
# 3     2014      1    1  -7275.474
# 4     2014      1    1  -7523.537
# ...    ...    ...  ...        ...
# 8755  2014     12   31 -47337.630
# 8756  2014     12   31 -43027.540
# 8757  2014     12   31 -39430.630
# 8758  2014     12   31 -35895.730
# 8759  2014     12   31 -33105.030
#
# [8760 rows x 4 columns]

# %%
plt.plot(dat)

# %%
da=pd.read_csv('GORIGO_2013SH.csv',names=['Year','Month','Day','Value'])

# %%
da
# Out:
#       Year  Month  Day      Value
# 0     2013      1    1  152125.00
# 1     2013      1    1  150709.10
# 2     2013      1    1  148789.80
# 3     2013      1    1  147908.80
# 4     2013      1    1  146146.80
# ...    ...    ...  ...        ...
# 8755  2013     12   31   19283.58
# 8756  2013     12   31   16514.74
# 8757  2013     12   31   16357.42
# 8758  2013     12   31   19377.97
# 8759  2013     12   31   34638.06
#
# [8760 rows x 4 columns]

# %%
plt.plot(da)

# %%
plt.plot(da.Month,da.Value)

# %%
dt=pd.read_csv('GORIGO_2014SH.csv',names=['Year','Month','Day','Value'])

# %%
dt
# Out:
#       Year  Month  Day      Value
# 0     2014      1    1   47982.16
# 1     2014      1    1   41969.51
# 2     2014      1    1   35800.27
# 3     2014      1    1   27282.35
# 4     2014      1    1   26812.61
# ...    ...    ...  ...        ...
# 8755  2014     12   31  136387.00
# 8756  2014     12   31  143902.80
# 8757  2014     12   31  141961.20
# 8758  2014     12   31  130155.10
# 8759  2014     12   31  120854.30
#
# [8760 rows x 4 columns]

# %%
plt.plot(dt)

# %%
plt.plot(dt.Month,dt.Value)

# %%
plt.plot(data.Month,data.Value,color='magenta',label='LH',ls='--',marker='P')
plt.plot(da.Month,da.Value,color='g',label='SH')
plt.title('LH AND SH FOR 2013')
plt.ylabel('$WM^-2$')
plt.xlabel('MONTH')
plt.legend()

# %%
plt.plot(dat.Month,dat.Value,color='r',label='LH',ls='--',marker='*')
plt.plot(dt.Month,dt.Value,color='g',label='SH')
plt.title('LH AND SH 14')
plt.ylabel('wm$^(-2)$')
plt.xlabel('MONTH')
plt.legend()

# %%
# Out:
# 22417.63
